# %%
import os
import pandas as pd
import uuid
from utils import xroad

# %%
# preliminaries
pref_code = '07' # two-digit num
city_code = '075035' # code list : https://www.soumu.go.jp/main_content/000925834.pdf
fetch_limit = 200
url = f'https://road-structures-db-bridge.mlit.go.jp/xROAD/api/v1/bridges?pref={pref_code}&city={city_code}&limit={fetch_limit}'

dacs_dataset_dir = './outputs/hiratamura_dacs_dataset'
if not os.path.exists(dacs_dataset_dir):
    os.makedirs(dacs_dataset_dir)

# %%
response_json = xroad.fetch_by_url(url)
total_bridges_num = response_json['resultset']['count']
result = response_json['result']
print('total # of bridges in the city: ', total_bridges_num)
if total_bridges_num > fetch_limit:
    print('fetch limit is too low, increase it to get all the bridges')
# Out:
# total # of bridges in the city:  114

# %%
success_dict = {}

for i in range(len(result)):
    shisetsu_id = result[i]['shisetsu_id']
    inspection_nendo = result[i]['tenken']['nendo']
    name = result[i]['syogen']['shisetsu']['meisyou']
    lat, lng = result[i]['syogen']['ichi'].values()
    point = f'("{lng}","{lat}")'
    data_id = f'i1_bridge_excel_{i}'

    save_file_name = f'{shisetsu_id}_{inspection_nendo}.xlsx'
    save_path = os.path.join(dacs_dataset_dir, data_id, save_file_name)
    if not os.path.exists(os.path.join(dacs_dataset_dir, data_id)):
        os.makedirs(os.path.join(dacs_dataset_dir, data_id))
    
    success = xroad.save_77_excel(shisetsu_id, inspection_nendo, save_path)
    if success:
        print(f'{shisetsu_id}_{inspection_nendo} saved')
        success_dict[str(i)] = {
            'root_ja':{
                'data_id': data_id,
                'title': name,            
                'point': point,
            },
            'files_ja':{
                'data_id': data_id,
                'file_id': uuid.uuid1(),
                'file': save_file_name
            }
        }
    else:
        print(f'{shisetsu_id}_{inspection_nendo} failed')
        # delete the directory
        os.rmdir(os.path.join(dacs_dataset_dir, data_id))
# Out:
# 37.17417,140.59528_2020 saved
# 37.16639,140.59333_2022 saved
# 37.20389,140.52611_2019 saved
# 37.22667,140.54750_2019 saved
# 37.23694,140.57111_2020 saved
# 37.23667,140.57111_2022 saved
# 37.22917,140.55278_2019 saved
# 37.17417,140.54111_2021 saved
# 37.18947,140.57292_2023 saved
# 37.20556,140.59056_2022 saved
# 37.17554,140.54461_2023 saved
# 37.16889,140.54194_2022 saved
# 37.18778,140.58556_2022 saved
# 37.21861,140.56889_2021 saved
# 37.21008,140.58154_2023 saved
# 37.20167,140.58972_2019 saved
# 37.20932,140.58204_2023 saved
# 37.17806,140.59333_2020 saved
# 37.21417,140.57556_2022 saved
# 37.23259,140.56854_2023 saved
# 37.20364,140.51138_2020 failed
# 37.20469,140.51633_2020 saved
# 37.20591,140.52205_2020 saved
# 37.20679,140.52185_2022 failed
# 37.21009,140.53764_2020 saved
# 37.22612,140.54635_2020 saved
# 37.22974,140.55218_2020 saved
# 37.23498,140.55620_2020 saved
# 37.23194,140.55472_2021 saved
# 37.21861,140.56861_2022 saved
# 37.23944,140.55583_2021 saved
# 37.25500,140.56361_2021 saved
# 37.26111,140.56694_2021 saved
# 37.24972,140.56111_2021 saved
# 37.24917,140.56111_2021 saved
# 37.24858,140.56046_2020 saved
# 37.23222,140.55500_2021 saved
# 37.24361,140.55722_2021 saved
# 37.24848,140.56055_2020 saved
# 37.24630,140.56946_2020 saved
# 37.24676,140.56564_2020 saved
# 37.24669,140.56933_2020 saved
# 37.25521,140.56221_2020 saved
# 37.21999,140.57709_2021 saved
# 37.23130,140.51608_2020 saved
# 37.25034,140.56557_2020 saved
# 37.24898,140.56605_2020 saved
# 37.24233,140.56311_2020 saved
# 37.17565,140.54699_2020 saved
# 37.24988,140.55964_2021 saved
# 37.22707,140.55443_2020 saved
# 37.21965,140.57484_2020 saved
# 37.23619,140.51255_2020 saved
# 37.22028,140.59091_2020 saved
# 37.22385,140.51781_2020 saved
# 37.23448,140.54665_2020 saved
# 37.21559,140.57466_2020 saved
# 37.22561,140.59578_2020 saved
# 37.22123,140.58599_2020 saved
# 37.24059,140.56611_2021 saved
# 37.24051,140.56807_2021 saved
# 37.22906,140.51860_2021 saved
# 37.22055,140.58098_2021 saved
# 37.22151,140.58844_2020 saved
# 37.24711,140.56403_2021 saved
# 37.22653,140.51706_2021 saved
# 37.18960,140.57756_2021 saved
# 37.24341,140.56769_2021 saved
# 37.18629,140.50872_2021 saved
# 37.21591,140.55817_2021 saved
# 37.24426,140.56739_2021 saved
# 37.24880,140.56025_2022 saved
# 37.20235,140.54718_2021 saved
# 37.23832,140.56875_2021 saved
# 37.23589,140.56901_2021 saved
# 37.19447,140.53756_2021 saved
# 37.18532,140.56316_2022 saved
# 37.18517,140.56583_2022 saved
# 37.17168,140.53882_2022 saved
# 37.21788,140.56956_2022 saved
# 37.18639,140.58361_2022 saved
# 37.18233,140.55473_2022 saved
# 37.18847,140.52413_2022 saved
# 37.18141,140.58886_2022 saved
# 37.18910,140.51577_2022 saved
# 37.18461,140.56374_2022 saved
# 37.18399,140.55528_2022 saved
# 37.21484,140.56648_2022 saved
# 37.20287,140.51200_2022 saved
# 37.17630,140.54645_2022 saved
# 37.19013,140.52367_2022 saved
# 37.21517,140.56930_2022 saved
# 37.19343,140.50843_2022 saved
# 37.17986,140.50984_2022 saved
# 37.18778,140.50306_2022 saved
# 37.19694,140.53972_2022 saved
# 37.19615,140.49952_2022 saved
# 37.21597,140.54186_2022 saved
# 37.20582,140.51931_2022 saved
# 37.22446,140.59908_2022 saved
# 37.23042,140.51846_2022 saved
# 37.21694,140.57139_2022 saved
# 37.23616,140.59022_2023 saved
# 37.22183,140.58319_2023 saved
# 37.19336,140.51080_2023 saved
# 37.20061,140.54741_2020 saved
# 37.21121,140.52656_2020 saved
# 37.18346,140.56711_2023 saved
# 37.25398,140.55834_2023 saved
# 37.24230,140.53698_2023 saved
# 37.24552,140.56736_2019 saved
# 37.24675,140.56518_2019 saved
# 37.24558,140.56746_2019 saved
# 37.24680,140.56526_2019 saved

# %%
success_dict
# Out:
# {'0': {'root_ja': {'data_id': 'i1_bridge_excel_0',
#    'title': '蕨平ボックスカルバート',
#    'point': '("37.174170","140.595280")'},
#   'files_ja': {'data_id': 'i1_bridge_excel_0',
#    'file_id': UUID('13e37566-60f9-11ef-871a-a08069f5749f'),
#    'file': '37.17417,140.59528_2020.xlsx'}},
#  '1': {'root_ja': {'data_id': 'i1_bridge_excel_1',
#    'title': '楢坂第１ボックスカルバート',
#    'point': '("37.166390","140.593330")'},
#   'files_ja': {'data_id': 'i1_bridge_excel_1',
#    'file_id': UUID('1828a984-60f9-11ef-871a-a08069f5749f'),
#    'file': '37.16639,140.59333_2022.xlsx'}},
#  '2': {'root_ja': {'data_id': 'i1_bridge_excel_2',
#    'title': '横川橋',
#    'point': '("37.203890","140.526110")'},
#   'files_ja': {'data_id': 'i1_bridge_excel_2',
#    'file_id': UUID('1c092664-60f9-11ef-871a-a08069f5749f'),
#    'file': '37.20389,140.52611_2019.xlsx'}},
#  '3': {'root_ja': {'data_id': 'i1_bridge_excel_3',
#    'title': '空釜橋',
#    'point': '("37.226670","140.547500")'},
#   'files_ja': {'data_id': 'i1_bridge_excel_3',
#    'file_id': UUID('20adf654-60f9-11ef-871a-a08069f5749f'),
#    'file': '37.22667,140.54750_2019.xlsx'}},
#  '4': {'root_ja': {'data_id': 'i1_bridge_excel_4',
#    'title': '大橋側道橋',
#    'point': '("37.236940","140.571110")'},
#   'files_ja': {'data_id': 'i1_bridge_excel_4',
#    'file_id': UUID('24854bd8-60f9-11ef-871a-a08069f5749f'),
#    'file': '37.23694,140.57111_2020.xlsx'}},
#  '5': {'root_ja': {'data_id': 'i1_bridge_excel_5',
#    'title': '大橋',
#    'point': '("37.236670","140.571110")'},
#   'files_ja': {'data_id': 'i1_bridge_excel_5',
#    'file_id': UUID('2907dcde-60f9-11ef-871a-a08069f5749f'),
#    'file': '37.23667,140.57111_2022.xlsx'}},
#  '6': {'root_ja': {'data_id': 'i1_bridge_excel_6',
#    'title': '関根橋',
#    'point': '("37.229170","140.552780")'},
#   'files_ja': {'data_id': 'i1_bridge_excel_6',
#    'file_id': UUID('2c4b9480-60f9-11ef-871a-a08069f5749f'),
#    'file': '37.22917,140.55278_2019.xlsx'}},
#  '7': {'root_ja': {'data_id': 'i1_bridge_excel_7',
#    'title': '暮坪橋',
#    'point': '("37.174170","140.541110")'},
#   'files_ja': {'data_id': 'i1_bridge_excel_7',
#    'file_id': UUID('3168908a-60f9-11ef-871a-a08069f5749f'),
#    'file': '37.17417,140.54111_2021.xlsx'}},
#  '8': {'root_ja': {'data_id': 'i1_bridge_excel_8',
#    'title': '轡橋',
#    'point': '("37.189470","140.572920")'},
#   'files_ja': {'data_id': 'i1_bridge_excel_8',
#    'file_id': UUID('348f86c4-60f9-11ef-871a-a08069f5749f'),
#    'file': '37.18947,140.57292_2023.xlsx'}},
#  '9': {'root_ja': {'data_id': 'i1_bridge_excel_9',
#    'title': '和久前橋',
#    'point': '("37.205560","140.590560")'},
#   'files_ja': {'data_id': 'i1_bridge_excel_9',
#    'file_id': UUID('388cdf9c-60f9-11ef-871a-a08069f5749f'),
#    'file': '37.20556,140.59056_2022.xlsx'}},
#  '10': {'root_ja': {'data_id': 'i1_bridge_excel_10',
#    'title': '下田橋',
#    'point': '("37.175540","140.544610")'},
#   'files_ja': {'data_id': 'i1_bridge_excel_10',
#    'file_id': UUID('3d71b7f8-60f9-11ef-871a-a08069f5749f'),
#    'file': '37.17554,140.54461_2023.xlsx'}},
#  '11': {'root_ja': {'data_id': 'i1_bridge_excel_11',
#    'title': '見上橋',
#    'point': '("37.168890","140.541940")'},
#   'files_ja': {'data_id': 'i1_bridge_excel_11',
#    'file_id': UUID('41dd4a00-60f9-11ef-871a-a08069f5749f'),
#    'file': '37.16889,140.54194_2022.xlsx'}},
#  '12': {'root_ja': {'data_id': 'i1_bridge_excel_12',
#    'title': '橋場橋',
#    'point': '("37.187780","140.585560")'},
#   'files_ja': {'data_id': 'i1_bridge_excel_12',
#    'file_id': UUID('45ebd9f4-60f9-11ef-871a-a08069f5749f'),
#    'file': '37.18778,140.58556_2022.xlsx'}},
#  '13': {'root_ja': {'data_id': 'i1_bridge_excel_13',
#    'title': '川端橋',
#    'point': '("37.218610","140.568890")'},
#   'files_ja': {'data_id': 'i1_bridge_excel_13',
#    'file_id': UUID('49427bee-60f9-11ef-871a-a08069f5749f'),
#    'file': '37.21861,140.56889_2021.xlsx'}},
#  '14': {'root_ja': {'data_id': 'i1_bridge_excel_14',
#    'title': '中橋',
#    'point': '("37.210080","140.581540")'},
#   'files_ja': {'data_id': 'i1_bridge_excel_14',
#    'file_id': UUID('4cd0f4f2-60f9-11ef-871a-a08069f5749f'),
#    'file': '37.21008,140.58154_2023.xlsx'}},
#  '15': {'root_ja': {'data_id': 'i1_bridge_excel_15',
#    'title': '地我橋',
#    'point': '("37.201670","140.589720")'},
#   'files_ja': {'data_id': 'i1_bridge_excel_15',
#    'file_id': UUID('50fdcf28-60f9-11ef-871a-a08069f5749f'),
#    'file': '37.20167,140.58972_2019.xlsx'}},
#  '16': {'root_ja': {'data_id': 'i1_bridge_excel_16',
#    'title': '柳橋',
#    'point': '("37.209320","140.582040")'},
#   'files_ja': {'data_id': 'i1_bridge_excel_16',
#    'file_id': UUID('5559270c-60f9-11ef-871a-a08069f5749f'),
#    'file': '37.20932,140.58204_2023.xlsx'}},
#  '17': {'root_ja': {'data_id': 'i1_bridge_excel_17',
#    'title': '蕨平橋',
#    'point': '("37.178060","140.593330")'},
#   'files_ja': {'data_id': 'i1_bridge_excel_17',
#    'file_id': UUID('59cba508-60f9-11ef-871a-a08069f5749f'),
#    'file': '37.17806,140.59333_2020.xlsx'}},
#  '18': {'root_ja': {'data_id': 'i1_bridge_excel_18',
#    'title': '旗杭橋',
#    'point': '("37.214170","140.575560")'},
#   'files_ja': {'data_id': 'i1_bridge_excel_18',
#    'file_id': UUID('5da36c7e-60f9-11ef-871a-a08069f5749f'),
#    'file': '37.21417,140.57556_2022.xlsx'}},
#  '19': {'root_ja': {'data_id': 'i1_bridge_excel_19',
#    'title': '遠藤橋',
#    'point': '("37.232590","140.568540")'},
#   'files_ja': {'data_id': 'i1_bridge_excel_19',
#    'file_id': UUID('60bd7bf2-60f9-11ef-871a-a08069f5749f'),
#    'file': '37.23259,140.56854_2023.xlsx'}},
#  '21': {'root_ja': {'data_id': 'i1_bridge_excel_21',
#    'title': '西山１号橋',
#    'point': '("37.204690","140.516330")'},
#   'files_ja': {'data_id': 'i1_bridge_excel_21',
#    'file_id': UUID('68fcd48e-60f9-11ef-871a-a08069f5749f'),
#    'file': '37.20469,140.51633_2020.xlsx'}},
#  '22': {'root_ja': {'data_id': 'i1_bridge_excel_22',
#    'title': '平田西インター橋',
#    'point': '("37.205910","140.522050")'},
#   'files_ja': {'data_id': 'i1_bridge_excel_22',
#    'file_id': UUID('6d1430c6-60f9-11ef-871a-a08069f5749f'),
#    'file': '37.20591,140.52205_2020.xlsx'}},
#  '24': {'root_ja': {'data_id': 'i1_bridge_excel_24',
#    'title': '西山２号橋',
#    'point': '("37.210090","140.537640")'},
#   'files_ja': {'data_id': 'i1_bridge_excel_24',
#    'file_id': UUID('738982a8-60f9-11ef-871a-a08069f5749f'),
#    'file': '37.21009,140.53764_2020.xlsx'}},
#  '25': {'root_ja': {'data_id': 'i1_bridge_excel_25',
#    'title': '下蓬田橋',
#    'point': '("37.226120","140.546350")'},
#   'files_ja': {'data_id': 'i1_bridge_excel_25',
#    'file_id': UUID('76a9ba48-60f9-11ef-871a-a08069f5749f'),
#    'file': '37.22612,140.54635_2020.xlsx'}},
#  '26': {'root_ja': {'data_id': 'i1_bridge_excel_26',
#    'title': '中屋敷橋',
#    'point': '("37.229740","140.552180")'},
#   'files_ja': {'data_id': 'i1_bridge_excel_26',
#    'file_id': UUID('7a7de3a6-60f9-11ef-871a-a08069f5749f'),
#    'file': '37.22974,140.55218_2020.xlsx'}},
#  '27': {'root_ja': {'data_id': 'i1_bridge_excel_27',
#    'title': '武名坂橋',
#    'point': '("37.234980","140.556200")'},
#   'files_ja': {'data_id': 'i1_bridge_excel_27',
#    'file_id': UUID('7d9605be-60f9-11ef-871a-a08069f5749f'),
#    'file': '37.23498,140.55620_2020.xlsx'}},
#  '28': {'root_ja': {'data_id': 'i1_bridge_excel_28',
#    'title': '下蓬田６',
#    'point': '("37.231940","140.554720")'},
#   'files_ja': {'data_id': 'i1_bridge_excel_28',
#    'file_id': UUID('81bde5a8-60f9-11ef-871a-a08069f5749f'),
#    'file': '37.23194,140.55472_2021.xlsx'}},
#  '29': {'root_ja': {'data_id': 'i1_bridge_excel_29',
#    'title': '川端橋側道橋',
#    'point': '("37.218610","140.568610")'},
#   'files_ja': {'data_id': 'i1_bridge_excel_29',
#    'file_id': UUID('858ad8d0-60f9-11ef-871a-a08069f5749f'),
#    'file': '37.21861,140.56861_2022.xlsx'}},
#  '30': {'root_ja': {'data_id': 'i1_bridge_excel_30',
#    'title': '横森前橋',
#    'point': '("37.239440","140.555830")'},
#   'files_ja': {'data_id': 'i1_bridge_excel_30',
#    'file_id': UUID('8a2a90ce-60f9-11ef-871a-a08069f5749f'),
#    'file': '37.23944,140.55583_2021.xlsx'}},
#  '31': {'root_ja': {'data_id': 'i1_bridge_excel_31',
#    'title': '曲山橋',
#    'point': '("37.255000","140.563610")'},
#   'files_ja': {'data_id': 'i1_bridge_excel_31',
#    'file_id': UUID('911a4190-60f9-11ef-871a-a08069f5749f'),
#    'file': '37.25500,140.56361_2021.xlsx'}},
#  '32': {'root_ja': {'data_id': 'i1_bridge_excel_32',
#    'title': '上蓬田-7',
#    'point': '("37.261110","140.566940")'},
#   'files_ja': {'data_id': 'i1_bridge_excel_32',
#    'file_id': UUID('94ecaf9c-60f9-11ef-871a-a08069f5749f'),
#    'file': '37.26111,140.56694_2021.xlsx'}},
#  '33': {'root_ja': {'data_id': 'i1_bridge_excel_33',
#    'title': '中根橋（下り）',
#    'point': '("37.249720","140.561110")'},
#   'files_ja': {'data_id': 'i1_bridge_excel_33',
#    'file_id': UUID('9a2717ea-60f9-11ef-871a-a08069f5749f'),
#    'file': '37.24972,140.56111_2021.xlsx'}},
#  '34': {'root_ja': {'data_id': 'i1_bridge_excel_34',
#    'title': '中根橋（上り）',
#    'point': '("37.249170","140.561110")'},
#   'files_ja': {'data_id': 'i1_bridge_excel_34',
#    'file_id': UUID('9f41b758-60f9-11ef-871a-a08069f5749f'),
#    'file': '37.24917,140.56111_2021.xlsx'}},
#  '35': {'root_ja': {'data_id': 'i1_bridge_excel_35',
#    'title': '北須川橋（下り）',
#    'point': '("37.248580","140.560460")'},
#   'files_ja': {'data_id': 'i1_bridge_excel_35',
#    'file_id': UUID('a2a033ac-60f9-11ef-871a-a08069f5749f'),
#    'file': '37.24858,140.56046_2020.xlsx'}},
#  '36': {'root_ja': {'data_id': 'i1_bridge_excel_36',
#    'title': '上蓬田１',
#    'point': '("37.232220","140.555000")'},
#   'files_ja': {'data_id': 'i1_bridge_excel_36',
#    'file_id': UUID('a7f00904-60f9-11ef-871a-a08069f5749f'),
#    'file': '37.23222,140.55500_2021.xlsx'}},
#  '37': {'root_ja': {'data_id': 'i1_bridge_excel_37',
#    'title': '上蓬田２',
#    'point': '("37.243610","140.557220")'},
#   'files_ja': {'data_id': 'i1_bridge_excel_37',
#    'file_id': UUID('ac9c9012-60f9-11ef-871a-a08069f5749f'),
#    'file': '37.24361,140.55722_2021.xlsx'}},
#  '38': {'root_ja': {'data_id': 'i1_bridge_excel_38',
#    'title': '北須川橋（上り）',
#    'point': '("37.248480","140.560550")'},
#   'files_ja': {'data_id': 'i1_bridge_excel_38',
#    'file_id': UUID('b0a3e2fa-60f9-11ef-871a-a08069f5749f'),
#    'file': '37.24848,140.56055_2020.xlsx'}},
#  '39': {'root_ja': {'data_id': 'i1_bridge_excel_39',
#    'title': '23号橋',
#    'point': '("37.246300","140.569460")'},
#   'files_ja': {'data_id': 'i1_bridge_excel_39',
#    'file_id': UUID('b39ef4b8-60f9-11ef-871a-a08069f5749f'),
#    'file': '37.24630,140.56946_2020.xlsx'}},
#  '40': {'root_ja': {'data_id': 'i1_bridge_excel_40',
#    'title': '32号橋',
#    'point': '("37.246760","140.565640")'},
#   'files_ja': {'data_id': 'i1_bridge_excel_40',
#    'file_id': UUID('b650e46e-60f9-11ef-871a-a08069f5749f'),
#    'file': '37.24676,140.56564_2020.xlsx'}},
#  '41': {'root_ja': {'data_id': 'i1_bridge_excel_41',
#    'title': '22号橋',
#    'point': '("37.246690","140.569330")'},
#   'files_ja': {'data_id': 'i1_bridge_excel_41',
#    'file_id': UUID('b9955a56-60f9-11ef-871a-a08069f5749f'),
#    'file': '37.24669,140.56933_2020.xlsx'}},
#  '42': {'root_ja': {'data_id': 'i1_bridge_excel_42',
#    'title': '29号橋',
#    'point': '("37.255210","140.562210")'},
#   'files_ja': {'data_id': 'i1_bridge_excel_42',
#    'file_id': UUID('bd128550-60f9-11ef-871a-a08069f5749f'),
#    'file': '37.25521,140.56221_2020.xlsx'}},
#  '43': {'root_ja': {'data_id': 'i1_bridge_excel_43',
#    'title': '64号橋',
#    'point': '("37.219990","140.577090")'},
#   'files_ja': {'data_id': 'i1_bridge_excel_43',
#    'file_id': UUID('c135ba9e-60f9-11ef-871a-a08069f5749f'),
#    'file': '37.21999,140.57709_2021.xlsx'}},
#  '44': {'root_ja': {'data_id': 'i1_bridge_excel_44',
#    'title': '43号橋',
#    'point': '("37.231300","140.516080")'},
#   'files_ja': {'data_id': 'i1_bridge_excel_44',
#    'file_id': UUID('c48adbde-60f9-11ef-871a-a08069f5749f'),
#    'file': '37.23130,140.51608_2020.xlsx'}},
#  '45': {'root_ja': {'data_id': 'i1_bridge_excel_45',
#    'title': '30号橋',
#    'point': '("37.250340","140.565570")'},
#   'files_ja': {'data_id': 'i1_bridge_excel_45',
#    'file_id': UUID('c82edd58-60f9-11ef-871a-a08069f5749f'),
#    'file': '37.25034,140.56557_2020.xlsx'}},
#  '46': {'root_ja': {'data_id': 'i1_bridge_excel_46',
#    'title': '31号橋',
#    'point': '("37.248980","140.566050")'},
#   'files_ja': {'data_id': 'i1_bridge_excel_46',
#    'file_id': UUID('cbf523c0-60f9-11ef-871a-a08069f5749f'),
#    'file': '37.24898,140.56605_2020.xlsx'}},
#  '47': {'root_ja': {'data_id': 'i1_bridge_excel_47',
#    'title': '39号橋',
#    'point': '("37.242330","140.563110")'},
#   'files_ja': {'data_id': 'i1_bridge_excel_47',
#    'file_id': UUID('cf6478da-60f9-11ef-871a-a08069f5749f'),
#    'file': '37.24233,140.56311_2020.xlsx'}},
#  '48': {'root_ja': {'data_id': 'i1_bridge_excel_48',
#    'title': 'あゆみ橋',
#    'point': '("37.175650","140.546990")'},
#   'files_ja': {'data_id': 'i1_bridge_excel_48',
#    'file_id': UUID('d31d3cb4-60f9-11ef-871a-a08069f5749f'),
#    'file': '37.17565,140.54699_2020.xlsx'}},
#  '49': {'root_ja': {'data_id': 'i1_bridge_excel_49',
#    'title': 'きずな橋',
#    'point': '("37.249880","140.559640")'},
#   'files_ja': {'data_id': 'i1_bridge_excel_49',
#    'file_id': UUID('d6a55876-60f9-11ef-871a-a08069f5749f'),
#    'file': '37.24988,140.55964_2021.xlsx'}},
#  '50': {'root_ja': {'data_id': 'i1_bridge_excel_50',
#    'title': '52号橋',
#    'point': '("37.227070","140.554430")'},
#   'files_ja': {'data_id': 'i1_bridge_excel_50',
#    'file_id': UUID('da3dcc7a-60f9-11ef-871a-a08069f5749f'),
#    'file': '37.22707,140.55443_2020.xlsx'}},
#  '51': {'root_ja': {'data_id': 'i1_bridge_excel_51',
#    'title': '63号橋',
#    'point': '("37.219650","140.574840")'},
#   'files_ja': {'data_id': 'i1_bridge_excel_51',
#    'file_id': UUID('dd328bc8-60f9-11ef-871a-a08069f5749f'),
#    'file': '37.21965,140.57484_2020.xlsx'}},
#  '52': {'root_ja': {'data_id': 'i1_bridge_excel_52',
#    'title': '44号橋',
#    'point': '("37.236190","140.512550")'},
#   'files_ja': {'data_id': 'i1_bridge_excel_52',
#    'file_id': UUID('e06780c8-60f9-11ef-871a-a08069f5749f'),
#    'file': '37.23619,140.51255_2020.xlsx'}},
#  '53': {'root_ja': {'data_id': 'i1_bridge_excel_53',
#    'title': '26号橋',
#    'point': '("37.220280","140.590910")'},
#   'files_ja': {'data_id': 'i1_bridge_excel_53',
#    'file_id': UUID('e450d068-60f9-11ef-871a-a08069f5749f'),
#    'file': '37.22028,140.59091_2020.xlsx'}},
#  '54': {'root_ja': {'data_id': 'i1_bridge_excel_54',
#    'title': '46号橋',
#    'point': '("37.223850","140.517810")'},
#   'files_ja': {'data_id': 'i1_bridge_excel_54',
#    'file_id': UUID('e809df9c-60f9-11ef-871a-a08069f5749f'),
#    'file': '37.22385,140.51781_2020.xlsx'}},
#  '55': {'root_ja': {'data_id': 'i1_bridge_excel_55',
#    'title': '48号橋',
#    'point': '("37.234480","140.546650")'},
#   'files_ja': {'data_id': 'i1_bridge_excel_55',
#    'file_id': UUID('eb8eaec2-60f9-11ef-871a-a08069f5749f'),
#    'file': '37.23448,140.54665_2020.xlsx'}},
#  '56': {'root_ja': {'data_id': 'i1_bridge_excel_56',
#    'title': '66号橋',
#    'point': '("37.215590","140.574660")'},
#   'files_ja': {'data_id': 'i1_bridge_excel_56',
#    'file_id': UUID('eec41c94-60f9-11ef-871a-a08069f5749f'),
#    'file': '37.21559,140.57466_2020.xlsx'}},
#  '57': {'root_ja': {'data_id': 'i1_bridge_excel_57',
#    'title': '25号橋',
#    'point': '("37.225610","140.595780")'},
#   'files_ja': {'data_id': 'i1_bridge_excel_57',
#    'file_id': UUID('f2115d30-60f9-11ef-871a-a08069f5749f'),
#    'file': '37.22561,140.59578_2020.xlsx'}},
#  '58': {'root_ja': {'data_id': 'i1_bridge_excel_58',
#    'title': '65号橋',
#    'point': '("37.221230","140.585990")'},
#   'files_ja': {'data_id': 'i1_bridge_excel_58',
#    'file_id': UUID('f5c1b344-60f9-11ef-871a-a08069f5749f'),
#    'file': '37.22123,140.58599_2020.xlsx'}},
#  '59': {'root_ja': {'data_id': 'i1_bridge_excel_59',
#    'title': '三斗蒔橋',
#    'point': '("37.240590","140.566110")'},
#   'files_ja': {'data_id': 'i1_bridge_excel_59',
#    'file_id': UUID('f974b356-60f9-11ef-871a-a08069f5749f'),
#    'file': '37.24059,140.56611_2021.xlsx'}},
#  '60': {'root_ja': {'data_id': 'i1_bridge_excel_60',
#    'title': '38号橋',
#    'point': '("37.240510","140.568070")'},
#   'files_ja': {'data_id': 'i1_bridge_excel_60',
#    'file_id': UUID('fcf65688-60f9-11ef-871a-a08069f5749f'),
#    'file': '37.24051,140.56807_2021.xlsx'}},
#  '61': {'root_ja': {'data_id': 'i1_bridge_excel_61',
#    'title': '42号橋',
#    'point': '("37.229060","140.518600")'},
#   'files_ja': {'data_id': 'i1_bridge_excel_61',
#    'file_id': UUID('00d5edd6-60fa-11ef-871a-a08069f5749f'),
#    'file': '37.22906,140.51860_2021.xlsx'}},
#  '62': {'root_ja': {'data_id': 'i1_bridge_excel_62',
#    'title': '酒州橋',
#    'point': '("37.220550","140.580980")'},
#   'files_ja': {'data_id': 'i1_bridge_excel_62',
#    'file_id': UUID('04b79684-60fa-11ef-871a-a08069f5749f'),
#    'file': '37.22055,140.58098_2021.xlsx'}},
#  '63': {'root_ja': {'data_id': 'i1_bridge_excel_63',
#    'title': '24号橋',
#    'point': '("37.221510","140.588440")'},
#   'files_ja': {'data_id': 'i1_bridge_excel_63',
#    'file_id': UUID('08aad3e6-60fa-11ef-871a-a08069f5749f'),
#    'file': '37.22151,140.58844_2020.xlsx'}},
#  '64': {'root_ja': {'data_id': 'i1_bridge_excel_64',
#    'title': '35号橋',
#    'point': '("37.247110","140.564030")'},
#   'files_ja': {'data_id': 'i1_bridge_excel_64',
#    'file_id': UUID('0cec8cc4-60fa-11ef-871a-a08069f5749f'),
#    'file': '37.24711,140.56403_2021.xlsx'}},
#  '65': {'root_ja': {'data_id': 'i1_bridge_excel_65',
#    'title': '荻ノ目橋',
#    'point': '("37.226530","140.517060")'},
#   'files_ja': {'data_id': 'i1_bridge_excel_65',
#    'file_id': UUID('10777066-60fa-11ef-871a-a08069f5749f'),
#    'file': '37.22653,140.51706_2021.xlsx'}},
#  '66': {'root_ja': {'data_id': 'i1_bridge_excel_66',
#    'title': '御坊地橋',
#    'point': '("37.189600","140.577560")'},
#   'files_ja': {'data_id': 'i1_bridge_excel_66',
#    'file_id': UUID('13794f6e-60fa-11ef-871a-a08069f5749f'),
#    'file': '37.18960,140.57756_2021.xlsx'}},
#  '67': {'root_ja': {'data_id': 'i1_bridge_excel_67',
#    'title': '清水内橋',
#    'point': '("37.243410","140.567690")'},
#   'files_ja': {'data_id': 'i1_bridge_excel_67',
#    'file_id': UUID('172405dc-60fa-11ef-871a-a08069f5749f'),
#    'file': '37.24341,140.56769_2021.xlsx'}},
#  '68': {'root_ja': {'data_id': 'i1_bridge_excel_68',
#    'title': '中町橋',
#    'point': '("37.186290","140.508720")'},
#   'files_ja': {'data_id': 'i1_bridge_excel_68',
#    'file_id': UUID('1b705fb4-60fa-11ef-871a-a08069f5749f'),
#    'file': '37.18629,140.50872_2021.xlsx'}},
#  '69': {'root_ja': {'data_id': 'i1_bridge_excel_69',
#    'title': '萬霊塔橋',
#    'point': '("37.215910","140.558170")'},
#   'files_ja': {'data_id': 'i1_bridge_excel_69',
#    'file_id': UUID('1f0376d4-60fa-11ef-871a-a08069f5749f'),
#    'file': '37.21591,140.55817_2021.xlsx'}},
#  '70': {'root_ja': {'data_id': 'i1_bridge_excel_70',
#    'title': '納豆橋',
#    'point': '("37.244260","140.567390")'},
#   'files_ja': {'data_id': 'i1_bridge_excel_70',
#    'file_id': UUID('22b24f76-60fa-11ef-871a-a08069f5749f'),
#    'file': '37.24426,140.56739_2021.xlsx'}},
#  '71': {'root_ja': {'data_id': 'i1_bridge_excel_71',
#    'title': '薬師地蔵橋',
#    'point': '("37.248800","140.560250")'},
#   'files_ja': {'data_id': 'i1_bridge_excel_71',
#    'file_id': UUID('262f564e-60fa-11ef-871a-a08069f5749f'),
#    'file': '37.24880,140.56025_2022.xlsx'}},
#  '72': {'root_ja': {'data_id': 'i1_bridge_excel_72',
#    'title': '沼ノ平橋',
#    'point': '("37.202350","140.547180")'},
#   'files_ja': {'data_id': 'i1_bridge_excel_72',
#    'file_id': UUID('2a86f92c-60fa-11ef-871a-a08069f5749f'),
#    'file': '37.20235,140.54718_2021.xlsx'}},
#  '73': {'root_ja': {'data_id': 'i1_bridge_excel_73',
#    'title': '橋本橋',
#    'point': '("37.238320","140.568750")'},
#   'files_ja': {'data_id': 'i1_bridge_excel_73',
#    'file_id': UUID('2e15f188-60fa-11ef-871a-a08069f5749f'),
#    'file': '37.23832,140.56875_2021.xlsx'}},
#  '74': {'root_ja': {'data_id': 'i1_bridge_excel_74',
#    'title': '馬道橋',
#    'point': '("37.235890","140.569010")'},
#   'files_ja': {'data_id': 'i1_bridge_excel_74',
#    'file_id': UUID('31f848d2-60fa-11ef-871a-a08069f5749f'),
#    'file': '37.23589,140.56901_2021.xlsx'}},
#  '75': {'root_ja': {'data_id': 'i1_bridge_excel_75',
#    'title': '板堰橋',
#    'point': '("37.194470","140.537560")'},
#   'files_ja': {'data_id': 'i1_bridge_excel_75',
#    'file_id': UUID('35bc47d4-60fa-11ef-871a-a08069f5749f'),
#    'file': '37.19447,140.53756_2021.xlsx'}},
#  '76': {'root_ja': {'data_id': 'i1_bridge_excel_76',
#    'title': '滝坂2号橋',
#    'point': '("37.185320","140.563160")'},
#   'files_ja': {'data_id': 'i1_bridge_excel_76',
#    'file_id': UUID('398eb658-60fa-11ef-871a-a08069f5749f'),
#    'file': '37.18532,140.56316_2022.xlsx'}},
#  '77': {'root_ja': {'data_id': 'i1_bridge_excel_77',
#    'title': '逆水橋',
#    'point': '("37.185170","140.565830")'},
#   'files_ja': {'data_id': 'i1_bridge_excel_77',
#    'file_id': UUID('3d96de24-60fa-11ef-871a-a08069f5749f'),
#    'file': '37.18517,140.56583_2022.xlsx'}},
#  '78': {'root_ja': {'data_id': 'i1_bridge_excel_78',
#    'title': '新日の出橋',
#    'point': '("37.171680","140.538820")'},
#   'files_ja': {'data_id': 'i1_bridge_excel_78',
#    'file_id': UUID('4186b3b0-60fa-11ef-871a-a08069f5749f'),
#    'file': '37.17168,140.53882_2022.xlsx'}},
#  '79': {'root_ja': {'data_id': 'i1_bridge_excel_79',
#    'title': '広町橋',
#    'point': '("37.217880","140.569560")'},
#   'files_ja': {'data_id': 'i1_bridge_excel_79',
#    'file_id': UUID('45a8b330-60fa-11ef-871a-a08069f5749f'),
#    'file': '37.21788,140.56956_2022.xlsx'}},
#  '80': {'root_ja': {'data_id': 'i1_bridge_excel_80',
#    'title': '小舘橋',
#    'point': '("37.186390","140.583610")'},
#   'files_ja': {'data_id': 'i1_bridge_excel_80',
#    'file_id': UUID('49243480-60fa-11ef-871a-a08069f5749f'),
#    'file': '37.18639,140.58361_2022.xlsx'}},
#  '81': {'root_ja': {'data_id': 'i1_bridge_excel_81',
#    'title': '岡谷橋',
#    'point': '("37.182330","140.554730")'},
#   'files_ja': {'data_id': 'i1_bridge_excel_81',
#    'file_id': UUID('4d977aea-60fa-11ef-871a-a08069f5749f'),
#    'file': '37.18233,140.55473_2022.xlsx'}},
#  '82': {'root_ja': {'data_id': 'i1_bridge_excel_82',
#    'title': '柳橋',
#    'point': '("37.188470","140.524130")'},
#   'files_ja': {'data_id': 'i1_bridge_excel_82',
#    'file_id': UUID('50e7d424-60fa-11ef-871a-a08069f5749f'),
#    'file': '37.18847,140.52413_2022.xlsx'}},
#  '83': {'root_ja': {'data_id': 'i1_bridge_excel_83',
#    'title': '孫内橋',
#    'point': '("37.181410","140.588860")'},
#   'files_ja': {'data_id': 'i1_bridge_excel_83',
#    'file_id': UUID('54f146d6-60fa-11ef-871a-a08069f5749f'),
#    'file': '37.18141,140.58886_2022.xlsx'}},
#  '84': {'root_ja': {'data_id': 'i1_bridge_excel_84',
#    'title': '油畑橋',
#    'point': '("37.189100","140.515770")'},
#   'files_ja': {'data_id': 'i1_bridge_excel_84',
#    'file_id': UUID('58e39370-60fa-11ef-871a-a08069f5749f'),
#    'file': '37.18910,140.51577_2022.xlsx'}},
#  '85': {'root_ja': {'data_id': 'i1_bridge_excel_85',
#    'title': '滝坂橋',
#    'point': '("37.184610","140.563740")'},
#   'files_ja': {'data_id': 'i1_bridge_excel_85',
#    'file_id': UUID('5d45b768-60fa-11ef-871a-a08069f5749f'),
#    'file': '37.18461,140.56374_2022.xlsx'}},
#  '86': {'root_ja': {'data_id': 'i1_bridge_excel_86',
#    'title': '下町橋',
#    'point': '("37.183990","140.555280")'},
#   'files_ja': {'data_id': 'i1_bridge_excel_86',
#    'file_id': UUID('60eacd86-60fa-11ef-871a-a08069f5749f'),
#    'file': '37.18399,140.55528_2022.xlsx'}},
#  '87': {'root_ja': {'data_id': 'i1_bridge_excel_87',
#    'title': '和吉橋',
#    'point': '("37.214840","140.566480")'},
#   'files_ja': {'data_id': 'i1_bridge_excel_87',
#    'file_id': UUID('648e0f3e-60fa-11ef-871a-a08069f5749f'),
#    'file': '37.21484,140.56648_2022.xlsx'}},
#  '88': {'root_ja': {'data_id': 'i1_bridge_excel_88',
#    'title': '中西橋',
#    'point': '("37.202870","140.512000")'},
#   'files_ja': {'data_id': 'i1_bridge_excel_88',
#    'file_id': UUID('68cbcd66-60fa-11ef-871a-a08069f5749f'),
#    'file': '37.20287,140.51200_2022.xlsx'}},
#  '89': {'root_ja': {'data_id': 'i1_bridge_excel_89',
#    'title': '霜平橋',
#    'point': '("37.176300","140.546450")'},
#   'files_ja': {'data_id': 'i1_bridge_excel_89',
#    'file_id': UUID('6d14a672-60fa-11ef-871a-a08069f5749f'),
#    'file': '37.17630,140.54645_2022.xlsx'}},
#  '90': {'root_ja': {'data_id': 'i1_bridge_excel_90',
#    'title': '川面橋',
#    'point': '("37.190130","140.523670")'},
#   'files_ja': {'data_id': 'i1_bridge_excel_90',
#    'file_id': UUID('71493bb8-60fa-11ef-871a-a08069f5749f'),
#    'file': '37.19013,140.52367_2022.xlsx'}},
#  '91': {'root_ja': {'data_id': 'i1_bridge_excel_91',
#    'title': '金吾橋',
#    'point': '("37.215170","140.569300")'},
#   'files_ja': {'data_id': 'i1_bridge_excel_91',
#    'file_id': UUID('74e6ad14-60fa-11ef-871a-a08069f5749f'),
#    'file': '37.21517,140.56930_2022.xlsx'}},
#  '92': {'root_ja': {'data_id': 'i1_bridge_excel_92',
#    'title': '不動橋',
#    'point': '("37.193430","140.508430")'},
#   'files_ja': {'data_id': 'i1_bridge_excel_92',
#    'file_id': UUID('79264a1a-60fa-11ef-871a-a08069f5749f'),
#    'file': '37.19343,140.50843_2022.xlsx'}},
#  '93': {'root_ja': {'data_id': 'i1_bridge_excel_93',
#    'title': '鷹ノ巣弁天橋',
#    'point': '("37.179860","140.509840")'},
#   'files_ja': {'data_id': 'i1_bridge_excel_93',
#    'file_id': UUID('7d45e74a-60fa-11ef-871a-a08069f5749f'),
#    'file': '37.17986,140.50984_2022.xlsx'}},
#  '94': {'root_ja': {'data_id': 'i1_bridge_excel_94',
#    'title': '加畑橋',
#    'point': '("37.187780","140.503060")'},
#   'files_ja': {'data_id': 'i1_bridge_excel_94',
#    'file_id': UUID('80e11adc-60fa-11ef-871a-a08069f5749f'),
#    'file': '37.18778,140.50306_2022.xlsx'}},
#  '95': {'root_ja': {'data_id': 'i1_bridge_excel_95',
#    'title': '一本ノ内橋',
#    'point': '("37.196940","140.539720")'},
#   'files_ja': {'data_id': 'i1_bridge_excel_95',
#    'file_id': UUID('84d4e9a2-60fa-11ef-871a-a08069f5749f'),
#    'file': '37.19694,140.53972_2022.xlsx'}},
#  '96': {'root_ja': {'data_id': 'i1_bridge_excel_96',
#    'title': '平田大橋',
#    'point': '("37.196150","140.499520")'},
#   'files_ja': {'data_id': 'i1_bridge_excel_96',
#    'file_id': UUID('8882594a-60fa-11ef-871a-a08069f5749f'),
#    'file': '37.19615,140.49952_2022.xlsx'}},
#  '97': {'root_ja': {'data_id': 'i1_bridge_excel_97',
#    'title': '空釜跨道橋',
#    'point': '("37.215970","140.541860")'},
#   'files_ja': {'data_id': 'i1_bridge_excel_97',
#    'file_id': UUID('8c244d4c-60fa-11ef-871a-a08069f5749f'),
#    'file': '37.21597,140.54186_2022.xlsx'}},
#  '98': {'root_ja': {'data_id': 'i1_bridge_excel_98',
#    'title': '草場橋',
#    'point': '("37.205820","140.519310")'},
#   'files_ja': {'data_id': 'i1_bridge_excel_98',
#    'file_id': UUID('8fd6c3b6-60fa-11ef-871a-a08069f5749f'),
#    'file': '37.20582,140.51931_2022.xlsx'}},
#  '99': {'root_ja': {'data_id': 'i1_bridge_excel_99',
#    'title': '沢名橋',
#    'point': '("37.224460","140.599080")'},
#   'files_ja': {'data_id': 'i1_bridge_excel_99',
#    'file_id': UUID('93941a8a-60fa-11ef-871a-a08069f5749f'),
#    'file': '37.22446,140.59908_2022.xlsx'}},
#  '100': {'root_ja': {'data_id': 'i1_bridge_excel_100',
#    'title': '41号橋',
#    'point': '("37.230420","140.518460")'},
#   'files_ja': {'data_id': 'i1_bridge_excel_100',
#    'file_id': UUID('97dcc2d6-60fa-11ef-871a-a08069f5749f'),
#    'file': '37.23042,140.51846_2022.xlsx'}},
#  '101': {'root_ja': {'data_id': 'i1_bridge_excel_101',
#    'title': '佐吉橋',
#    'point': '("37.216940","140.571390")'},
#   'files_ja': {'data_id': 'i1_bridge_excel_101',
#    'file_id': UUID('9bc6e502-60fa-11ef-871a-a08069f5749f'),
#    'file': '37.21694,140.57139_2022.xlsx'}},
#  '102': {'root_ja': {'data_id': 'i1_bridge_excel_102',
#    'title': '77号橋',
#    'point': '("37.236160","140.590220")'},
#   'files_ja': {'data_id': 'i1_bridge_excel_102',
#    'file_id': UUID('9fb1a1ac-60fa-11ef-871a-a08069f5749f'),
#    'file': '37.23616,140.59022_2023.xlsx'}},
#  '103': {'root_ja': {'data_id': 'i1_bridge_excel_103',
#    'title': '1号橋',
#    'point': '("37.221830","140.583190")'},
#   'files_ja': {'data_id': 'i1_bridge_excel_103',
#    'file_id': UUID('a3779f1c-60fa-11ef-871a-a08069f5749f'),
#    'file': '37.22183,140.58319_2023.xlsx'}},
#  '104': {'root_ja': {'data_id': 'i1_bridge_excel_104',
#    'title': '山鶏の滝橋',
#    'point': '("37.193360","140.510800")'},
#   'files_ja': {'data_id': 'i1_bridge_excel_104',
#    'file_id': UUID('a70582f2-60fa-11ef-871a-a08069f5749f'),
#    'file': '37.19336,140.51080_2023.xlsx'}},
#  '105': {'root_ja': {'data_id': 'i1_bridge_excel_105',
#    'title': '55号橋',
#    'point': '("37.200610","140.547410")'},
#   'files_ja': {'data_id': 'i1_bridge_excel_105',
#    'file_id': UUID('ab403d58-60fa-11ef-871a-a08069f5749f'),
#    'file': '37.20061,140.54741_2020.xlsx'}},
#  '106': {'root_ja': {'data_id': 'i1_bridge_excel_106',
#    'title': '12号橋',
#    'point': '("37.211210","140.526560")'},
#   'files_ja': {'data_id': 'i1_bridge_excel_106',
#    'file_id': UUID('ae935882-60fa-11ef-871a-a08069f5749f'),
#    'file': '37.21121,140.52656_2020.xlsx'}},
#  '107': {'root_ja': {'data_id': 'i1_bridge_excel_107',
#    'title': '78号橋',
#    'point': '("37.183460","140.567110")'},
#   'files_ja': {'data_id': 'i1_bridge_excel_107',
#    'file_id': UUID('b28f5df0-60fa-11ef-871a-a08069f5749f'),
#    'file': '37.18346,140.56711_2023.xlsx'}},
#  '108': {'root_ja': {'data_id': 'i1_bridge_excel_108',
#    'title': '79号橋',
#    'point': '("37.253980","140.558340")'},
#   'files_ja': {'data_id': 'i1_bridge_excel_108',
#    'file_id': UUID('b67ecbee-60fa-11ef-871a-a08069f5749f'),
#    'file': '37.25398,140.55834_2023.xlsx'}},
#  '109': {'root_ja': {'data_id': 'i1_bridge_excel_109',
#    'title': '80号線',
#    'point': '("37.242300","140.536980")'},
#   'files_ja': {'data_id': 'i1_bridge_excel_109',
#    'file_id': UUID('ba3a7f94-60fa-11ef-871a-a08069f5749f'),
#    'file': '37.24230,140.53698_2023.xlsx'}},
#  '110': {'root_ja': {'data_id': 'i1_bridge_excel_110',
#    'title': '大隅橋',
#    'point': '("37.245520","140.567360")'},
#   'files_ja': {'data_id': 'i1_bridge_excel_110',
#    'file_id': UUID('bdf1a2a2-60fa-11ef-871a-a08069f5749f'),
#    'file': '37.24552,140.56736_2019.xlsx'}},
#  '111': {'root_ja': {'data_id': 'i1_bridge_excel_111',
#    'title': '横森橋',
#    'point': '("37.246750","140.565180")'},
#   'files_ja': {'data_id': 'i1_bridge_excel_111',
#    'file_id': UUID('c1a24140-60fa-11ef-871a-a08069f5749f'),
#    'file': '37.24675,140.56518_2019.xlsx'}},
#  '112': {'root_ja': {'data_id': 'i1_bridge_excel_112',
#    'title': '大隅橋側道橋',
#    'point': '("37.245580","140.567460")'},
#   'files_ja': {'data_id': 'i1_bridge_excel_112',
#    'file_id': UUID('c5735e9e-60fa-11ef-871a-a08069f5749f'),
#    'file': '37.24558,140.56746_2019.xlsx'}},
#  '113': {'root_ja': {'data_id': 'i1_bridge_excel_113',
#    'title': '横森橋側道橋',
#    'point': '("37.246800","140.565260")'},
#   'files_ja': {'data_id': 'i1_bridge_excel_113',
#    'file_id': UUID('c9644004-60fa-11ef-871a-a08069f5749f'),
#    'file': '37.24680,140.56526_2019.xlsx'}}}

# %%
# データフレームの作成
root_ja_df = pd.DataFrame(columns=["data_id", "title", "summary", "point", "archive_file"])
files_ja_df = pd.DataFrame(columns=["data_id", "file_id", "file"])

for key in success_dict.keys():
    root_ja_df.loc[key] = success_dict[key]['root_ja']
    files_ja_df.loc[key] = success_dict[key]['files_ja']
root_ja_df.fillna('')  # NaNを空文字に置換

# save meta data
with pd.ExcelWriter(os.path.join(dacs_dataset_dir, 'meta.xlsx'), engine='openpyxl') as writer:
    root_ja_df.to_excel(writer, sheet_name='root_ja', index=False)
    files_ja_df.to_excel(writer, sheet_name='files_ja', index=False)
